# %% [markdown]
# # DOMAIN: Medical
# • CONTEXT: Medical research university X is undergoing a deep research on patients with certain conditions. University has an internal AI team.
# Due to confidentiality the patient’s details and the conditions are masked by the client by providing different datasets to the AI team for developing a AIML model which can predict the condition of the patient depending on the received test result

# %% [markdown]
# # DATA DESCRIPTION:
#     The data consists of biomechanics features of the patients according to their current conditions. Each patient is
# represented in the data set by six biomechanics attributes derived from the shape and orientation of the condition to their body part.

# %% [markdown]
# #  PROJECT OBJECTIVE:
#     To Demonstrate the ability to fetch, process and leverage data to generate useful predictions by training Supervised
# Learning algorithms

# %% [markdown]
# # STEPS AND TASK [30 Marks]:
# # 1. Data Understanding: [5 Marks]
#
#
# B. Print Shape and columns of all the 3 DataFrames. [1 Mark]
# C. Compare Column names of all the 3 DataFrames and clearly write observations. [1 Mark]
# D. Print DataTypes of all the 3 DataFrames. [1 Mark]
# E. Observe and share variation in ‘Class’ feature of all the 3 DaraFrames. [1 Mark

# %%
# 1A. Read all the 3 CSV files as DataFrame and store them into 3 separate variables. [1 Mark]

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt # library used for plotting to visualise data 
# %matplotlib inline 
# The %matplotlib inline enables “inline plotting”, where plotted graphics appear in your notebook

# %%
# reading all 3 CSV files as Data Frame and storingn into 3 seperate variables

df1=pd.read_csv('Normal.csv')
df2=pd.read_csv('Type_H.csv')
df3=pd.read_csv('Type_S.csv')

# %%
#1B. Print Shape and columns of all the 3 DataFrames. [1 Mark]
df1.shape # to check number of rows and columns i.e 100 rows and 7 columns in 1st data frame in this case
# Out:
# (100, 7)

# %%
df1.info() # to check the attributes/column type of first data set
df1.head() # to check whether data loaded propoerly or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  100 non-null    float64
#  1   P_tilt       100 non-null    float64
#  2   L_angle      100 non-null    float64
#  3   S_slope      100 non-null    float64
#  4   P_radius     100 non-null    float64
#  5   S_Degree     100 non-null    float64
#  6   Class        100 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 5.6+ KB
#    P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree   Class
# 0    38.505273  16.964297  35.112814  21.540976  127.632875  7.986683  Normal
# 1    54.920858  18.968430  51.601455  35.952428  125.846646  2.001642  Normal
# 2    44.362490   8.945435  46.902096  35.417055  129.220682  4.994195  Normal
# 3    48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941  Normal
# ...

# %% [markdown]
# df2.shape

# %%
df2.shape # to check number of rows and columns i.e 60 rows and 7 columns in 2nd data frame in this case
# Out:
# (60, 7)

# %%
df2.info() #checking the attributes of 2nd dataset
df2.head() # checking for proper data loading in 2nd data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  60 non-null     float64
#  1   P_tilt       60 non-null     float64
#  2   L_angle      60 non-null     float64
#  3   S_slope      60 non-null     float64
#  4   P_radius     60 non-null     float64
#  5   S_Degree     60 non-null     float64
#  6   Class        60 non-null     object
# dtypes: float64(6), object(1)
# memory usage: 3.4+ KB
#    P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree   Class
# 0    63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400  Type_H
# 1    39.056951  10.060991  25.015378  28.995960  114.405425   4.564259  Type_H
# 2    68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317  Type_H
# 3    69.297008  24.652878  44.311238  44.644130  101.868495  11.211523  Type_H
# ...

# %%
df3.shape # to check number of rows and columns i.e 150 rows and 7 columns in 3rd data frame in this case
# Out:
# (150, 7)

# %%
df3.info() #checking the attributes of 3rd dataset
df3.head() # checking for proper data loading in 3rd data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  150 non-null    float64
#  1   P_tilt       150 non-null    float64
#  2   L_angle      150 non-null    float64
#  3   S_slope      150 non-null    float64
#  4   P_radius     150 non-null    float64
#  5   S_Degree     150 non-null    float64
#  6   Class        150 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 8.3+ KB
#    P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree   Class
# 0    74.377678  32.053104  78.772013  42.324573  143.560690  56.125906  Type_S
# 1    89.680567  32.704435  83.130732  56.976132  129.955476  92.027277  Type_S
# 2    44.529051   9.433234  52.000000  35.095817  134.711772  29.106575  Type_S
# 3    77.690577  21.380645  64.429442  56.309932  114.818751  26.931841  Type_S
# ...

# %%
# 1.C Compare Column names of all the 3 DataFrames and clearly write observations. [1 Mark]

# All the three data sets have same number of columns i.e 7 and column names are also same as below
# 1.P_incidence
# 2.P_tilt
# 3.L_angle
# 4.S_slope
# 5.P_radius
# 6.S_degree
# 7.Class

# %%
#1.D Print DataTypes of all the 3 DataFrames. [1 Mark]
df1.info()
df2.info()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  100 non-null    float64
#  1   P_tilt       100 non-null    float64
#  2   L_angle      100 non-null    float64
#  3   S_slope      100 non-null    float64
#  4   P_radius     100 non-null    float64
#  5   S_Degree     100 non-null    float64
#  6   Class        100 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 5.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P_incidence  60 non-null     float64
#  1   P_tilt       60 non-null     float64
#  2   L_angle      60 non-null     float64
#  3   S_slope      60 non-null     float64
#  4   P_radius     60 non-null     float64
# ...

# %%
# from the above Dtype in info() function gives the datatypes of columns and here there are 6 float64 type and 1 object type column in each data set

# %%
# 1E.Observe and share variation in ‘Class’ feature of all the 3 DataFrames. [1 Mark]

# while observing the data from the three data frames usind dataframe.head() , it is observed that they are differntiated with the values in 'class' column as below
# 1. Normal in 1st data frame 
# 2. Type_H in 2nd data frame
# 3. Type_S in 3rd data frame

# The value in 'class' feature is differentiating the data frames
df1['Class'].unique()
# Out:
# array(['Normal', 'Nrmal'], dtype=object)

# %%
# Counting the occurrences of each unique category
GroupedData1=df1.groupby(by='Class').size()
print(GroupedData1)
# Out:
# Class
# Normal    73
# Nrmal     27
# dtype: int64

# %%
GroupedData1.plot.bar()
# Out:
# <AxesSubplot:xlabel='Class'>

# %%
df2['Class'].unique()
# Out:
# array(['Type_H', 'type_h'], dtype=object)

# %%
GroupedData2=df2.groupby(by='Class').size()
print(GroupedData2)
# Out:
# Class
# Type_H    37
# type_h    23
# dtype: int64

# %%
GroupedData2.plot.bar()
# Out:
# <AxesSubplot:xlabel='Class'>

# %%
df3['Class'].unique()
# Out:
# array(['Type_S', 'tp_s'], dtype=object)

# %%
GroupedData3=df3.groupby(by='Class').size()
print(GroupedData3)
# Out:
# Class
# Type_S    133
# tp_s       17
# dtype: int64

# %%
GroupedData3.plot.bar()
# Out:
# <AxesSubplot:xlabel='Class'>

# %% [markdown]
# # 2.Data Preparation and Exploration: [5 Marks]

# %%
# 2A Unify all the variations in ‘Class’ feature for all the 3 DataFrames. [1 Marks]
df1.head()
df1copy=df1.copy()
df1copy.loc[df1copy['Class']=='Nrmal','Class']= 'Normal'
df1copy.head()
df1copy['Class'].unique()
df1copy.head()
# to unify the class feature checked for the unique values and conditionally changed the same to the desired value
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree   Class
# 0    38.505273  16.964297  35.112814  21.540976  127.632875  7.986683  Normal
# 1    54.920858  18.968430  51.601455  35.952428  125.846646  2.001642  Normal
# 2    44.362490   8.945435  46.902096  35.417055  129.220682  4.994195  Normal
# 3    48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941  Normal
# 4    45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910  Normal

# %%
df2.head()
df2copy=df2.copy()
df2copy.loc[df2copy['Class']=='type_h','Class']= 'Type_H'
df2copy.head()
df2copy['Class'].unique()
# to unify the class feature checked for the unique values and conditionally changed the same to the desired value
# Out:
# array(['Type_H'], dtype=object)

# %%
df3.head()
df3copy=df3.copy()
df3copy.loc[df3copy['Class']=='tp_s','Class']= 'Type_S'
df3copy.head()
df3copy['Class'].unique()
# to unify the class feature checked for the unique values and conditionally changed the same to the desired value
# Out:
# array(['Type_S'], dtype=object)

# %%
# 2B. Combine all the 3 DataFrames to form a single DataFrame [1 Marks]
# Merging all the 3 datasets over rows
Biomechanics = pd.concat([df1copy,df2copy,df3copy],axis=0,ignore_index=True,sort=False) 

Biomechanics['Class'].unique()
# Out:
# array(['Normal', 'Type_H', 'Type_S'], dtype=object)

# %%
Biomechanics.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree   Class
# 0    38.505273  16.964297  35.112814  21.540976  127.632875  7.986683  Normal
# 1    54.920858  18.968430  51.601455  35.952428  125.846646  2.001642  Normal
# 2    44.362490   8.945435  46.902096  35.417055  129.220682  4.994195  Normal
# 3    48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941  Normal
# 4    45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910  Normal

# %%
# shape of combined dataset
Biomechanics.shape
# There are 310 rows and 7 Columns in the combined Data Set
# Out:
# (310, 7)

# %%
#2C. Print 5 random samples of this DataFrame [1 Marks]
Biomechanics.sample(5)
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree  \
# 30     41.646916   8.835549  36.031975  32.811367  116.555168  -6.054538
# 281    64.624008  15.225303  67.632167  49.398705   90.298468  31.326411
# 251    48.030624   3.969815  58.344519  44.060809  125.350962  35.000078
# 180    77.106571  30.469994  69.480628  46.636577  112.151600  70.759083
# 71     64.261507  14.497866  43.902504  49.763642  115.388268   5.951454
#
#       Class
# 30   Normal
# 281  Type_S
# 251  Type_S
# 180  Type_S
# 71   Normal

# %%
#2D. Print Feature-wise percentage of Null values. [1 Mark]
#Biomechanics['Class'].value_counts() # There are 3 classes in the target variable.

# %%
Biomechanics.isnull().sum()
# Out:
# P_incidence    0
# P_tilt         0
# L_angle        0
# S_slope        0
# P_radius       0
# S_Degree       0
# Class          0
# dtype: int64

# %%
#2E. Check 5-point summary of the new DataFrame. [1 Mark]

Biomechanics.describe().transpose()
# Out:
#              count        mean        std        min         25%         50%  \
# P_incidence  310.0   60.496653  17.236520  26.147921   46.430294   58.691038
# P_tilt       310.0   17.542822  10.008330  -6.554948   10.667069   16.357689
# L_angle      310.0   51.930930  18.554064  14.000000   37.000000   49.562398
# S_slope      310.0   42.953831  13.423102  13.366931   33.347122   42.404912
# P_radius     310.0  117.920655  13.317377  70.082575  110.709196  118.268178
# S_Degree     310.0   26.296694  37.559027 -11.058179    1.603727   11.767934
#
#                     75%         max
# P_incidence   72.877696  129.834041
# P_tilt        22.120395   49.431864
# L_angle       63.000000  125.742385
# S_slope       52.695888  121.429566
# P_radius     125.467674  163.071041
# S_Degree      41.287352  418.543082

# %%
#3. Data Analysis: [10 Marks]
#A. Visualize a heatmap to understand correlation between all features [2 Marks]

#A heat map is a two-dimensional representation of information with the help of colors. 
#Heat maps can help the user visualize simple or complex information.

# To visualiase heatmap, the 'Class' fetaure should also need to be numerical
Biomechanics.iloc[:,6].unique()

# Use label encoder to convert categorical variables to one-hot encoding 

from sklearn.preprocessing import LabelEncoder
class_label_encoder = LabelEncoder()

Biomechanics.iloc[:,-1] = class_label_encoder.fit_transform(Biomechanics.iloc[:,-1])

# %%
Biomechanics.sample(5) # Check the encoded labels of target variable, 'Class'
# Out:
#      P_incidence     P_tilt    L_angle    S_slope    P_radius   S_Degree  \
# 69     48.801909  18.017762  52.000000  30.784147  139.150407  10.442862
# 208    63.172987   6.330911  63.000000  56.842076  110.644021  42.608076
# 14     89.834676  22.639217  90.563461  67.195460  100.501192   3.040973
# 275    56.563824   8.961262  52.577846  47.602562   98.777115  50.701873
# 67     65.756348  13.206926  44.000000  52.549422  129.393573  -1.982120
#
#      Class
# 69       0
# 208      2
# 14       0
# 275      2
# 67       0

# %%
corr=Biomechanics.corr()
corr
# Out:
#              P_incidence    P_tilt   L_angle   S_slope  P_radius  S_Degree  \
# P_incidence     1.000000  0.629199  0.717282  0.814960 -0.247467  0.638743
# P_tilt          0.629199  1.000000  0.432764  0.062345  0.032668  0.397862
# L_angle         0.717282  0.432764  1.000000  0.598387 -0.080344  0.533667
# S_slope         0.814960  0.062345  0.598387  1.000000 -0.342128  0.523557
# P_radius       -0.247467  0.032668 -0.080344 -0.342128  1.000000 -0.026065
# S_Degree        0.638743  0.397862  0.533667  0.523557 -0.026065  1.000000
# Class           0.537638  0.348231  0.525466  0.430734 -0.304099  0.608705
#
#                 Class
# P_incidence  0.537638
# P_tilt       0.348231
# L_angle      0.525466
# S_slope      0.430734
# P_radius    -0.304099
# S_Degree     0.608705
# Class        1.000000

# %%
# Pearson's Correlation Coefficient: helps you find out the relationship between two quantities.
#It gives you the measure of the strength of association between two variables. 
#The value of Pearson's Correlation Coefficient can be between -1 to +1. 1 means that they are highly correlated and 0 means no correlation.

# %%
plt.figure(figsize=(12,12))
sns.heatmap(corr,square=True,linecolor='white',linewidths=0.2, annot=True)
# Out:
# <AxesSubplot:>

# %%
# 3B. Share insights on correlation. [2 Marks]
#A. Features having stronger correlation with correlation value.

#Correlation between s_degree and p_incidence is stronger and the correlation value is 0.64

#B. Features having weaker correlation with correlation value

#Correlation between S_slope and p_radius is weaker and the correlation value is -0.34

# %%
#3C. Visualize a pairplot with 3 classes distinguished by colors and share insights. [2 Marks]

# Use pairplot to plot the distribution of each variable.
colormap= sns.color_palette("hls", 3)
sns.pairplot(Biomechanics, hue = 'Class',palette=colormap, diag_kind = 'kde')

# %% [markdown]
# # insights

# %% [markdown]
# # The data points of all the three classes are randomly distributed. There is not a strong correlation between any two variables.

# %%
# Type_s class is more compared to other two.
# Normal class has higher values compared to Type_H
# Along the diagonal we can see distribution of variable for three claases are not same.

# %%
# 3D. Visualize a jointplot for ‘P_incidence’ and ‘S_slope’ and share insights. [2 Marks]

#The Joint plot is consists of 3 separate plots. 
#In which one is the middle figure which is used to see the relationship between x and y. 
#This area gives us information about the joint distribution while the other two areas give us marginal distribution for the x and y-axis.

sns.jointplot(x = "P_incidence", y = "S_slope",
              kind = "hex", data = Biomechanics)
# show the plot
plt.show()

# %%
sns.jointplot(x = "P_incidence", y = "S_slope",
              kind = "scatter", data = Biomechanics)
# show the plot
plt.show()

# %%
sns.jointplot(x = "P_incidence", y = "S_slope",
              kind = "kde", data = Biomechanics)
# show the plot
plt.show()

# %%
sns.jointplot(x = "P_incidence", y = "S_slope",
              kind = "reg", data = Biomechanics)
# show the plot
plt.show()

# %%
# kind in jointplot syntax: The kind of plot to draw.
# insights:

#The varaibles P_incedence and S_slope are normally distributed but a little skewness towards right side

# %%
#5E. Visualize a boxplot to check distribution of the features and share insights. [2 Marks]

#The box plot distribution will explain how tightly the data is grouped, how the data is skewed, and also about the symmetry of data.

fig = plt.figure(figsize = (15,6))

ra1 = fig.add_subplot(1,3,1) 
ra2 = fig.add_subplot(1,3,2)
ra3 = fig.add_subplot(1,3,3)

ra1.hist(Biomechanics['P_tilt'],color = 'purple')
ra1.set_title('The Distribution of P_tilt')

ra2.hist(Biomechanics['P_radius'],color = 'blue')
ra2.set_title('The Distribution of P_radius')

ra3.hist(Biomechanics['S_Degree'],color = 'orange')
ra3.set_title('The Distribution of S_Degree')


plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('The Distribution of P_tilt')
sns.boxplot(Biomechanics['P_tilt'],color='purple')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('The Distribution of P_radius')
sns.boxplot(Biomechanics['P_radius'],orient='vertical',color= 'blue')

# subplot 3
plt.subplot(1, 3, 3)
plt.title('The Distribution of S_Degree')
sns.boxplot(Biomechanics['S_Degree'],color='orange')

plt.tight_layout() 
plt.show()
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ...

# %% [markdown]
# # insights

# %%
## 'P-tilt:'

#It has normal distribution but a little skewness towards right side.

#We can see one outlier in negative end and few outliers in positive side.

##'P_radius:'

# Data is normally distributed. We can see some outliers at both the sides.

#'S_Degree:'

#There are significant outliers and the data is Positively Skewed.

# %% [markdown]
# # Bivariate Analysis using boxplot

# %%
 #Observe the relation between all the independent variables and target variable
plt.figure(figsize=(20,15))

plt.subplot(3, 2, 1)
plt.title('The relatio of P_incidence with "Class"')
sns.boxplot(x='Class', y='P_incidence', data= Biomechanics)

plt.subplot(3, 2, 2)
plt.title('The relatio of P_tilt with "Class"')
sns.boxplot(x='Class', y='P_tilt', data= Biomechanics)

plt.subplot(3, 2, 3)
plt.title('The relatio of L_angle with "Class"')
sns.boxplot(x='Class', y='L_angle', data= Biomechanics)

plt.subplot(3, 2, 4)
plt.title('The relatio of S_slope with "Class"')
sns.boxplot(x='Class', y='S_slope', data= Biomechanics)

plt.subplot(3, 2, 5)
plt.title('The relatio of P_radius with "Class"')
sns.boxplot(x='Class', y='P_radius', data= Biomechanics)

plt.subplot(3, 2, 6)
plt.title('The relatio of S_Degree with "Class"')
sns.boxplot(x='Class', y='S_Degree', data= Biomechanics)

plt.show()

# %%
#P_Incidence Normal Value is slightly higher than Type_H, and for Type_S Class Value is larger.

#P_til Type_H is slightly higher than Normal Value, and for Type_S Class Value is larger.

#L_Angle It has higher value for Type_S Class and Normal class has higher values compared to type_H class. Each class contains one outlier

#S_slope has huge values for Type_S class

#P_radius Normal Class has more values. There are some extreme values for Type_s class

# S_Degree has large values for Type_S Class

# %% [markdown]
# # 4. Model Building: [6 Marks]

# %% [markdown]
# # 4A Split data into X and Y. [1 Marks]

# %%
# Data preprocessing 

#Perform normalisation or scaling if required.
Biomechanics.Class.value_counts(normalize=True)
# Out:
# 2    0.483871
# 0    0.322581
# 1    0.193548
# Name: Class, dtype: float64

# %%
#Normal: 0

#Type_H: 1

#Type_S: 2

# check for balanced target value 
Biomechanics.groupby(["Class"]).count()
# Out:
#        P_incidence  P_tilt  L_angle  S_slope  P_radius  S_Degree
# Class
# 0              100     100      100      100       100       100
# 1               60      60       60       60        60        60
# 2              150     150      150      150       150       150

# %%
# Create a separate dataframe consisting only of the features i.e independent attributes 
# and a dataframe of target variable

X = Biomechanics.drop(labels= "Class" , axis = 1) # Feature set
y = Biomechanics["Class"] # Target variable
X.head()
# Out:
#    P_incidence     P_tilt    L_angle    S_slope    P_radius  S_Degree
# 0    38.505273  16.964297  35.112814  21.540976  127.632875  7.986683
# 1    54.920858  18.968430  51.601455  35.952428  125.846646  2.001642
# 2    44.362490   8.945435  46.902096  35.417055  129.220682  4.994195
# 3    48.318931  17.452121  48.000000  30.866809  128.980308 -0.910941
# 4    45.701789  10.659859  42.577846  35.041929  130.178314 -3.388910

# %% [markdown]
# # Perform normalisation or scaling.
# Convert the features by performing standard scaling as we do not know what units / scales were used and store them in new dataframe.
#
# It is always advisable to bring all the features to the same scale for applying distance based algorithms like KNN.

# %%
#standardization of data

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

X_std = pd.DataFrame(StandardScaler().fit_transform(X))
X_std.columns = X.columns

# %%
X_std.head() # Scaled Features
# Out:
#    P_incidence    P_tilt   L_angle   S_slope  P_radius  S_Degree
# 0    -1.277922 -0.057898 -0.907904 -1.597803  0.730468 -0.488288
# 1    -0.324010  0.142672 -0.017786 -0.522437  0.596124 -0.647896
# 2    -0.937559 -0.860412 -0.271475 -0.562386  0.849889 -0.568091
# 3    -0.707649 -0.009077 -0.212206 -0.901920  0.831811 -0.725568
# 4    -0.859732 -0.688835 -0.504914 -0.590377  0.921914 -0.791650

# %%
#4B Split data into train and test with 80:20 proportion. [1 Marks]

#split the dataset into training and test datasets

from sklearn.model_selection import train_test_split

# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size=0.2,random_state=10) # for test size:20, train size will be 80

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (248, 6)
# (248,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (62, 6)
# (62,)

# %% [markdown]
# # 4C Train a Supervised Learning Classification base model using KNN classifier. [2 Marks]

# %%
# we can build the model and train and test on training and test sets respectively using scikit-learn.

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn.metrics import recall_score

Train_score =[]
Test_score =[]

for k in range(1,50):
    NNH = KNeighborsClassifier(n_neighbors = k, metric = 'euclidean', weights = 'distance' )
    NNH.fit(X_train, y_train)
    Train_score.append(NNH.score(X_train, y_train))
    Test_score.append(NNH.score(X_test, y_test))

# %%
plt.plot(range(1,50),Train_score)
plt.show()

# %%
# The model is overfitting on training dataset for all the values of k.

# %%
plt.plot(range(1,50),Test_score)
plt.show()

# %% [markdown]
# # On test data model have higher accuracies for value of k less than 15. Let's choose k less than 15 to find best value of k.

# %%
# 4D Print all the possible performance metrics for both train and test data. [2 Marks

# loading library
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn.metrics import recall_score

# instantiate learning model (k = 3)
knn = KNeighborsClassifier(n_neighbors = 3, weights = 'distance')

# fitting the model
knn.fit(X_train, y_train)

# predict the response
y_pred = knn.predict(X_test)

# evaluate accuracy and generate classification report
print('The accuracy score and Classification Report with K = 3 \n')
print('The model accuracy on test data is :' ,accuracy_score(y_test, y_pred),'\n')
print(classification_report(y_test, y_pred))

# instantiate learning model (k = 5)
knn = KNeighborsClassifier(n_neighbors=5, weights = 'distance')
# fitting the model
knn.fit(X_train, y_train)

# predict the response
y_pred = knn.predict(X_test)

# evaluate accuracy and generate classification report
print('The accuracy score and Classification Report with K = 5 \n')
print('The model accuracy on test data is :' ,accuracy_score(y_test, y_pred),'\n')
print(classification_report(y_test, y_pred))

# instantiate learning model (k = 7)
knn = KNeighborsClassifier(n_neighbors=7, weights = 'distance')

# fitting the model
knn.fit(X_train, y_train)

# predict the response
y_pred = knn.predict(X_test)

# evaluate accuracy and generate classification report
print('The accuracy score and Classification Report with K = 7 \n')
print('The model accuracy on test data is :' ,accuracy_score(y_test, y_pred),'\n')
print(classification_report(y_test, y_pred))
# Out:
# The accuracy score and Classification Report with K = 3
#
# The model accuracy on test data is : 0.7096774193548387
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.47      0.48        17
#            1       0.50      0.67      0.57        15
#            2       1.00      0.87      0.93        30
#
#     accuracy                           0.71        62
#    macro avg       0.67      0.67      0.66        62
# weighted avg       0.74      0.71      0.72        62
#
# The accuracy score and Classification Report with K = 5
#
# The model accuracy on test data is : 0.6935483870967742
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.59      0.54        17
#            1       0.50      0.60      0.55        15
#            2       1.00      0.80      0.89        30
#
#     accuracy                           0.69        62
#    macro avg       0.67      0.66      0.66        62
# ...

# %% [markdown]
# # For the given problem, the prediction is to be made about the patient's condition (normal or abnormal), thus False Negative (FN) predictions can lead to serious problem as the patient with abnormal condition will be treated as normal, and no treatment will be given.
#
# In such scenario Recall value plays an importance in determining model performance.
#
# Evaluating performance of the above models, it is observed that the KNN Classifier with K = 7 provide better Recall values and F1 Score compare to other models.
#
# Further it perform well on test data points of Class 2:"Type_S", as there more training samples of Class 2 are used in training Dataset. While for Class 0 - "Type_H" has less number of samples in training set.

# %% [markdown]
# # 5. Performance Improvement: [4 Marks]

# %% [markdown]
# # Computing the confusion Matrix

# %%
#5A Experiment with various parameters to improve performance of the base model. [2 Marks]

from sklearn import metrics

cm =metrics.confusion_matrix(y_test,y_pred)
print('The Confusion Matrix :\n',cm)

colormap = plt.cm.inferno
plt.figure(figsize=(10,10))
sns.heatmap(cm, xticklabels=['NORMAL_ACTUAL', 'TYPE_H__ACTUAL','TYPE_S__ACTUAL'],yticklabels= ['NORMAL_PREDICT', 'TYPE_H_PREDICT','TYPE_S_PREDICT'],square=True, cmap=colormap, linecolor='white', linewidths= 0.2, annot=True)
# Out:
# The Confusion Matrix :
#  [[ 9  7  1]
#  [ 4 11  0]
#  [ 5  1 24]]
# <AxesSubplot:>

# %%
#There are some False Negative values for the Class "Normal" and "Type_H".

#The prediction of class "Type_S" has no errors.

# %% [markdown]
# # Automate the task of finding best values of K for KNN.

# %%
# creating list of K as odd values for KNN
myList = list(range(1,20))

# subsetting just the odd ones
neighbors = list(filter(lambda x: x % 2 != 0, myList))

# %%
# empty list that will hold accuracy scores
ac_scores = []
Recall_scores =[]

# perform accuracy metrics for values from 1,3,5....19
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    # predict the response
    y_pred = knn.predict(X_test)
    # evaluate accuracy
    scores = accuracy_score(y_test, y_pred)
    ac_scores.append(scores)
    # Evaluate Recall Score
    scores_r = recall_score(y_test, y_pred,average='macro')
    Recall_scores.append(scores_r)

# changing to misclassification error
MSE = [1 - x for x in ac_scores]
MSE_R = [1 - x for x in Recall_scores]

# determining best k based on accuracy score
optimal_k = neighbors[MSE.index(min(MSE))]
print("Based on accuracy score, The optimal number of neighbors is %d" % optimal_k)

# determining best k based on Recall score
optimal_k_R = neighbors[MSE_R.index(min(MSE_R))]
print("Based on Recall score, The optimal number of neighbors is %d" % optimal_k_R)
# Out:
# Based on accuracy score, The optimal number of neighbors is 11
# Based on Recall score, The optimal number of neighbors is 17

# %% [markdown]
# # THE FINAL BEST MODEL USING K=11

# %%
# Use k=17 as the final model for prediction

knn = KNeighborsClassifier(n_neighbors =11,weights='distance')

# fitting the model
knn.fit(X_train, y_train)

# predict the response
y_pred = knn.predict(X_test)

# evaluate accuracy and Recall scores
print('The Training Score :{:.2f}'.format(knn.score(X_train,y_train)*100))
print('The Test Score :{:.2f}'.format(knn.score(X_test,y_test)*100),'\n')

print('The accuracy score of final trained model on test data is: {:.2f}'.format(accuracy_score(y_test, y_pred)))
print('The Recall score of final trained model on test data is : {:.2f}'.format(recall_score(y_test, y_pred,average='macro')))
# Out:
# The Training Score :100.00
# The Test Score :75.81
#
# The accuracy score of final trained model on test data is: 0.76
# The Recall score of final trained model on test data is : 0.74

# %% [markdown]
# #

# %%
#Training Acuracy is 100 % and Testing Accuracy is 73%. Performance is less in test data.

#This is due to overfitting of data

# %% [markdown]
# # Performance Evaluation of the Final Model.

# %%
#computing Confusion Matrix
from sklearn import metrics


cm =metrics.confusion_matrix(y_test,y_pred)
print('The Confusion Matrix :\n',cm)

colormap = plt.cm.YlGnBu
plt.figure(figsize=(10,10))
sns.heatmap(cm, xticklabels=['NORMAL_ACTUAL', 'TYPE_H__ACTUAL','TYPE_S__ACTUAL'],yticklabels= ['NORMAL_PREDICT', 'TYPE_H_PREDICT','TYPE_S_PREDICT'],square=True, cmap=colormap, linecolor='black', linewidths =0.5,annot=True)
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Predicted label')
plt.xlabel('Actual label')
# Out:
# The Confusion Matrix :
#  [[10  6  1]
#  [ 3 12  0]
#  [ 4  1 25]]
# Text(0.5, 155.72222222222217, 'Actual label')

# %%
# Classification Report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59        17
#            1       0.63      0.80      0.71        15
#            2       0.96      0.83      0.89        30
#
#     accuracy                           0.76        62
#    macro avg       0.73      0.74      0.73        62
# weighted avg       0.78      0.76      0.76        62

# %%
#Classification report shows the precision, recall, F1 and support scores for the classification model.

#Precision of 2 ('Type_S') represents that for all patients predicted as Type_S, the percentage of patients that actually have Type_S iS 100 %.

# Recall is the ability of a classifier to find all positive instances. Recall of 2 indicates that for all patients that actually DO NOT have Type_S disease, the model predicts 100 % correctly that patients do not have Type_S disease.

#Similar explanation can be INFERED FOR OTHER classes(0 and 1) I.E NORMAL AND type_H

# %% [markdown]
# # 5C Clearly showcase improvement in performance achieved. [1 Marks]
# For Example:
# A. Accuracy: +15% improvement
# B. Precision: +10% improvement

# %%
# Here Accuracy imporved from 71% to 73% i.e 2.81% improvement

# Precision imporved from ) 96% to 100% i.e 4.16 % imporvement

# %%
#5C Clearly state which parameters contributed most to improve model performance. [1 Marks]

# Optimal value of K contributed most to improve the model performance
# High training accuracy and Low test accuracy ( out of sample accuracy ) = High Variance = Over-fitting model = More model complexity.

# %% [markdown]
# # PART B
#
# DOMAIN: Banking, Marketing
# • CONTEXT: A bank X is on a massive digital transformation for all its departments. Bank has a growing customer base whee majority of them are
# liability customers (depositors) vs borrowers (asset customers). The bank is interested in expanding the borrowers base rapidly to bring in more
# business via loan interests. A campaign that the bank ran in last quarter showed an average single digit conversion rate. Digital transformation
# being the core strength of the business strategy, marketing department wants to devise effective campaigns with better target marketing to
# increase the conversion ratio to double digit with same budget as per last campaign.
# • DATA DICTIONARY:
# 1. Team: Team’s name
# 2. ID: Customer ID
# 3. Age: Customer’s approximate age.
# 4. CustomerSince: Customer of the bank since. [unit is masked]
# 5. HighestSpend: Customer’s highest spend so far in one transaction. [unit is masked]
# 6. ZipCode: Customer’s zip code.
# 7. HiddenScore: A score associated to the customer which is masked by the bank as an IP.
# 8. MonthlyAverageSpend: Customer’s monthly average spend so far. [unit is masked]
# 9. Level: A level associated to the customer which is masked by the bank as an IP.
# 10. Mortgage: Customer’s mortgage. [unit is masked]
# 11. Security: Customer’s security asset with the bank. [unit is masked]
# 12. FixedDepositAccount: Customer’s fixed deposit account with the bank. [unit is masked]
# 13. InternetBanking: if the customer uses internet banking.
# 14. CreditCard: if the customer uses bank’s credit card.
# 15. LoanOnCard: if the customer has a loan on credit card.
# • PROJECT OBJECTIVE: Build a Machine Learning model to perform focused marketing by predicting the potential customers who will convert using the historical dataset.

# %% [markdown]
# # STEPS AND TASK [30 Marks]:
# 1. Data Understanding and Preparation: [5 Marks]

# %%
# A. Read both the Datasets ‘Data1’ and ‘Data 2’ as DataFrame and store them into two separate variables. [1 Marks]

dfD1 = pd.read_csv('Data1.csv')
dfD2 = pd.read_csv('Data2.csv')

# %%
# B. Print shape and Column Names and DataTypes of both the Dataframes. [1 Marks]

dfD1.shape
#contains 8 columns
# Out:
# (5000, 8)

# %%
dfD2.shape
#contains 7 columns
# Out:
# (5000, 7)

# %%
# use info for datatypes observation
dfD1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Age                  5000 non-null   int64
#  2   CustomerSince        5000 non-null   int64
#  3   HighestSpend         5000 non-null   int64
#  4   ZipCode              5000 non-null   int64
#  5   HiddenScore          5000 non-null   int64
#  6   MonthlyAverageSpend  5000 non-null   float64
#  7   Level                5000 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 312.6 KB

# %%
dfD2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Mortgage             5000 non-null   int64
#  2   Security             5000 non-null   int64
#  3   FixedDepositAccount  5000 non-null   int64
#  4   InternetBanking      5000 non-null   int64
#  5   CreditCard           5000 non-null   int64
#  6   LoanOnCard           4980 non-null   float64
# dtypes: float64(1), int64(6)
# memory usage: 273.6 KB

# %%
#C Merge both the Dataframes on ‘ID’ feature to form a single DataFrame [2 Marks]

#Both the dataset has ID ie: customer ID as the common column to merge with. 
#By merging 2 dataset's we will have more columns (More features) to check for relationship.

data = pd.merge(dfD1,dfD2,how='inner',on='ID')

# %%
data.shape
#Post merging we see 14 features
# Out:
# (5000, 14)

# %%
# Data Cleansing
# Explore and if required correct the datatypes of each attribute
#Over here we only see integers and floats which is an added advantage but we notice few null values in "LoanOnCard" column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Age                  5000 non-null   int64
#  2   CustomerSince        5000 non-null   int64
#  3   HighestSpend         5000 non-null   int64
#  4   ZipCode              5000 non-null   int64
#  5   HiddenScore          5000 non-null   int64
#  6   MonthlyAverageSpend  5000 non-null   float64
#  7   Level                5000 non-null   int64
#  8   Mortgage             5000 non-null   int64
#  9   Security             5000 non-null   int64
#  10  FixedDepositAccount  5000 non-null   int64
#  11  InternetBanking      5000 non-null   int64
#  12  CreditCard           5000 non-null   int64
#  13  LoanOnCard           4980 non-null   float64
# dtypes: float64(2), int64(12)
# memory usage: 585.9 KB

# %%
#Over here we only see integers and floats which is an added advantage but we notice few null values in "LoanOnCard" column

# %%
# Change Datatype of below features to ‘Object’ [1 Marks]
# ‘CreditCard’, ‘InternetBanking’, ‘FixedDepositAccount’, ‘Security’, ‘Level’, ‘HiddenScore’

data = data.astype({'CreditCard': np.object, 'InternetBanking': np.object,'FixedDepositAccount': np.object, 'Security': np.object,'Level': np.object,'HiddenScore': np.object })
# Out:
# C:\Users\91984\AppData\Local\Temp\ipykernel_32188\1359909897.py:4: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data = data.astype({'CreditCard': np.object, 'InternetBanking': np.object,'FixedDepositAccount': np.object, 'Security': np.object,'Level': np.object,'HiddenScore': np.object })

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   5000 non-null   int64
#  1   Age                  5000 non-null   int64
#  2   CustomerSince        5000 non-null   int64
#  3   HighestSpend         5000 non-null   int64
#  4   ZipCode              5000 non-null   int64
#  5   HiddenScore          5000 non-null   object
#  6   MonthlyAverageSpend  5000 non-null   float64
#  7   Level                5000 non-null   object
#  8   Mortgage             5000 non-null   int64
#  9   Security             5000 non-null   object
#  10  FixedDepositAccount  5000 non-null   object
#  11  InternetBanking      5000 non-null   object
#  12  CreditCard           5000 non-null   object
#  13  LoanOnCard           4980 non-null   float64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 585.9+ KB

# %% [markdown]
# # 2. Data Exploration and Analysis: [5 Marks]

# %%
# A. Visualize distribution of Target variable ‘LoanOnCard’ and clearly share insights. [2 Marks]
sns.countplot(data['LoanOnCard'])
# LoanOnCard is  completely imbalanced target class and having missing values
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanOnCard', ylabel='count'>

# %%
data.corr()['LoanOnCard'].sort_values(ascending=False)
#correlations on the LoanOnCard
# Out:
# LoanOnCard             1.000000
# HighestSpend           0.502626
# MonthlyAverageSpend    0.366912
# Mortgage               0.141947
# ZipCode                0.000120
# CustomerSince         -0.007801
# Age                   -0.008147
# ID                    -0.027188
# Name: LoanOnCard, dtype: float64

# %% [markdown]
# # ID and Zipcode being the nominal type data has no role to play in prediction - dropping both

# %%
# B. Check the percentage of missing values and impute if required. [1 Marks]
#Imputation can be done using any of the below techniques–

#Impute by mean
#Impute by median
#Knn Imputation

# %%
data.isnull().sum()
# Out:
# ID                      0
# Age                     0
# CustomerSince           0
# HighestSpend            0
# ZipCode                 0
# HiddenScore             0
# MonthlyAverageSpend     0
# Level                   0
# Mortgage                0
# Security                0
# FixedDepositAccount     0
# InternetBanking         0
# CreditCard              0
# LoanOnCard             20
# dtype: int64

# %%
# 20 missing values in 'LoanOncard'
# percentage of missing values is 20/5000 * 100= 0.4 only
# imputation may not be required as only 0.4 % data is missing and so the null values can be dropped
#Also there is 4980 entries which is enough to train a model with 70% data (3486 rows - 70% for training and 1494 for testing)#

# %%
# C. Check for unexpected values in each categorical variable and impute with best suitable value. [2 Marks]
#Hint: Unexpected values means if all values in a feature are 0/1 then ‘?’, ‘a’, 1.5 are unexpected values which needs treatment

# check for cateogorical variable from data
data
# Out:
#         ID  Age  CustomerSince  HighestSpend  ZipCode HiddenScore  \
# 0        1   25              1            49    91107           4
# 1        2   45             19            34    90089           3
# 2        3   39             15            11    94720           1
# 3        4   35              9           100    94112           1
# 4        5   35              8            45    91330           4
# ...    ...  ...            ...           ...      ...         ...
# 4995  4996   29              3            40    92697           1
# 4996  4997   30              4            15    92037           4
# 4997  4998   63             39            24    93023           2
# 4998  4999   65             40            49    90034           3
# 4999  5000   28              4            83    92612           3
#
#       MonthlyAverageSpend Level  Mortgage Security FixedDepositAccount  \
# 0                     1.6     1         0        1                   0
# ...

# %%
data['Security'].unique()
# Out:
# array([1, 0], dtype=object)

# %%
data['FixedDepositAccount'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
data['InternetBanking'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
data['CreditCard'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
data['LoanOnCard'].unique()
# Out:
# array([nan,  1.,  0.])

# %%
# couldnt find any unexpected values and hence imputation is not required

# %% [markdown]
# # 3. Data Preparation and model building: [10 Marks]

# %%
# A. Split data into X and Y. [1 Marks]
data1 = data.dropna(axis=0)
# Dropping the null 20 rows and creating a new Dataframe named data1

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4980 entries, 9 to 4999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   4980 non-null   int64
#  1   Age                  4980 non-null   int64
#  2   CustomerSince        4980 non-null   int64
#  3   HighestSpend         4980 non-null   int64
#  4   ZipCode              4980 non-null   int64
#  5   HiddenScore          4980 non-null   object
#  6   MonthlyAverageSpend  4980 non-null   float64
#  7   Level                4980 non-null   object
#  8   Mortgage             4980 non-null   int64
#  9   Security             4980 non-null   object
#  10  FixedDepositAccount  4980 non-null   object
#  11  InternetBanking      4980 non-null   object
#  12  CreditCard           4980 non-null   object
#  13  LoanOnCard           4980 non-null   float64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 583.6+ KB

# %%
data1 = data1.drop(['ID','ZipCode'],axis=1) # dropping both ID and Zipcode being the nominal type data has no role to play in prediction

# %%
# to split to X and Y need to identify the correlation between variables to check what to need to put in X and Y

# %%
sns.distplot(data1['HighestSpend'])
#data is continuous and skewed
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HighestSpend', ylabel='Density'>

# %%
sns.boxplot(data1['HighestSpend'])
#data does have outliers
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HighestSpend'>

# %%
sns.barplot('LoanOnCard','HighestSpend',data=data1)
## In general When the highest spend value increases the tendency to take loan also increases
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanOnCard', ylabel='HighestSpend'>

# %%
sns.boxplot('LoanOnCard','HighestSpend',data=data1)
# there are people who spend high but still end up not purchasing, this is an outlier in class 0.0 for loan on card
# Outliers tend to affect our prediction while making the model
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanOnCard', ylabel='HighestSpend'>

# %%
sns.distplot(data1['MonthlyAverageSpend'])
#data is continuous and skewed
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MonthlyAverageSpend', ylabel='Density'>

# %%
sns.boxplot(data1['MonthlyAverageSpend'])
# It holds a lot of outliers, we need to check the impact made by these outliers
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MonthlyAverageSpend'>

# %%
sns.boxplot('LoanOnCard','MonthlyAverageSpend',data=data1)
# there are people who have high monthly average spend but still end up not purchasing any loans, this outlier is displayed in class 0.0 for loan on card
# Outliers like these affect our prediction while making the model
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanOnCard', ylabel='MonthlyAverageSpend'>

# %%
sns.barplot('LoanOnCard','MonthlyAverageSpend',data=data1)
## In general When the monthly average spend value increases the tendency to take loan also increases
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanOnCard', ylabel='MonthlyAverageSpend'>

# %%
sns.countplot(data1['FixedDepositAccount'])
#Data is categorical
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FixedDepositAccount', ylabel='count'>

# %%
# Those who have more monthly average spend tend to 
sns.boxplot(x ='FixedDepositAccount', y ='MonthlyAverageSpend', data = data1, hue ='LoanOnCard')
# Out:
# <AxesSubplot:xlabel='FixedDepositAccount', ylabel='MonthlyAverageSpend'>

# %%
# Those who have FD account have more tendency to take loan if their monthly spend is also high, those who do not have FD account
# mostly don tend to get loans unless their monthly spend is high, in general FD account holders tend to get loans

# %%
sns.boxplot('LoanOnCard','Mortgage',data=data1)
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanOnCard', ylabel='Mortgage'>

# %%
sns.boxplot(x ='FixedDepositAccount', y ='Mortgage', data = data1, hue ='LoanOnCard') 
#This shows the people who mortgage end up getting loan but the level of difference the we find is less
# Out:
# <AxesSubplot:xlabel='FixedDepositAccount', ylabel='Mortgage'>

# %%
data1['Level'].unique()
#Categorical feature
# Out:
# array([3, 2, 1], dtype=object)

# %%
sns.boxplot(x ='Level', y ='HighestSpend', data = data1, hue ='LoanOnCard')
# Out:
# <AxesSubplot:xlabel='Level', ylabel='HighestSpend'>

# %%
# HiddenScore,Security,InternetBanking,CreditCard,CustomerSince,Age - All these feature play a very lesser role as they
# are more correlated with the internal features, they can be used to discover new columns or fill missing columns

# %%
X = data1.drop(['LoanOnCard','HiddenScore','Security','InternetBanking','CreditCard','CustomerSince','Age'],axis=1)
y = data1['LoanOnCard'] # target attribute

# %%
# B. Split data into train and test. Keep 25% data reserved for testing. [1 Marks]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %%
# C. Train a Supervised Learning Classification base model - Logistic Regression. [2 Marks]

from sklearn.model_selection import KFold,train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

LR = LogisticRegression()

# %%
LR.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
LR.score(X_train,y_train)
#score of training data
# Out:
# 0.9459170013386881

# %%
prediction = LR.predict(X_test)

# %%
postpred = pd.DataFrame(prediction,columns = ['Predicted data'])

# %%
postpred['Actual data'] = y_test.values

# %%
#D.Print evaluation metrics for the model and clearly share insights. [1 Marks]
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      1121
#          1.0       0.84      0.61      0.71       124
#
#     accuracy                           0.95      1245
#    macro avg       0.90      0.80      0.84      1245
# weighted avg       0.95      0.95      0.95      1245

# %%
#insight

#Usually we focus only on Precision and we see that class 0's precision is 96% which is good but class 1 precision is 84% which can be better
#F1 score being a tradeoff of both precision and recall can also be seen where it has 97% for class 0 and 71% for class 1
#In this case we focus more on Recall as the company's target is to increase conversion ratio, get more loaners and also we will see precission, 
#the reason is that we cannot afford to incorrectly classify someone as positive (ie) we cannot incorrectly call a person as positive(to repay) whereas the person is actually No. 
#This causes more loss to a banking sector, they can afford to loose someone who might pay the loan which causes a loss but they cannot afford to give loan to someone who is incorrectly classified as will pay

# %%
# E.Balance the data using the right balancing technique. [2 Marks]
#i. Check distribution of the target variable
#ii. Say output is class A : 20% and class B : 80%
#iii. Here you need to balance the target variable as 50:50.
# iv. Try appropriate method to achieve the same

# %%
print(y.value_counts())

#Highly imbalanced - definetly needs a fix
# It can be fixed by using Precision (how many we predicted as postive and how many were actually
# positive), because we cannot afford to have False positive (predicting someone will return but actually they dont)
# and the other metric to look into is F1 score which is a tradeoff of both precision n recall
# Out:
# 0.0    4500
# 1.0     480
# Name: LoanOnCard, dtype: int64

# %%
# output shows that class A data is 9 times more of Class B.

# %% [markdown]
# # Balancing the Target Variable 'LoanOnCard' using SMOTE(Synthetic Minority Over-sampling Technique)
# Working with imbalanced datasets in most machine learning techniques will have poor performance on, the minority class, although typically it is performance on the minority class that is most important.
#
# One approach to addressing imbalanced datasets is to oversample the minority class. The simplest approach involves duplicating examples in the minority class, although these examples don’t add any new information to the model. Instead, new examples can be synthesized from the existing examples. This is a type of data augmentation for the minority class and is referred to as the Synthetic Minority Oversampling Technique, or SMOTE for short.

# %%
# import library for balancing the data using oversampling.

from sklearn.datasets import make_classification
#from unbalanced_dataset import UnderSampler, OverSampler, SMOTE

from imblearn.over_sampling import SMOTE

# %%
   
    sm = SMOTE(random_state=23, sampling_strategy=1.0)
    X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)
    print(len(X_train_sm), len(y_train_sm))
# Out:
# 6152 6152

# %%
X1 = data.drop('LoanOnCard',axis=1)
y1 = data['LoanOnCard']

# %%
# as unable to import Smote , to balance the data outliers may be removed

# %%
print(y.value_counts())
# Out:
# 0.0    4105
# 1.0     480
# Name: LoanOnCard, dtype: int64

# %% [markdown]
# # We know for a fact that class 0 being highly imbalanced contains a lot of outliers which we noticed in above visualization plots. We can eliminate these outliers which would help in creating better model and also reduces the imbalance in classes

# %%
# Any observations that is 1.5 times more than Q3 or 1.5 times less than Q1, considered as outliers.

# %%
# drop unnecessary columns
data1 = data1.drop(['HiddenScore','Security','InternetBanking','CreditCard','CustomerSince','Age'],axis=1)

# %%
data1 = data1.sort_values('HighestSpend')
columns = ['HighestSpend','MonthlyAverageSpend','Mortgage']
#sort the data
def remove_outliers(x):
    for c in columns:
        Q1 = np.percentile(x[c],25)
        Q2 = np.percentile(x[c],50)
        Q3 = np.percentile(x[c],75)
        IQR = Q3-Q1
        lower_outliers = Q1 -(1.5 * IQR) 
        upper_outliers = Q3 +(1.5 * IQR) 
        print(f"For {c} :")
        print(f"The IQR is {IQR}")
        print(f"The value above {upper_outliers} and value below {lower_outliers} will be considered as outliers")
        print(data1[(data1[c]>upper_outliers)|(data1[c]<lower_outliers)]['LoanOnCard'].value_counts())
        print("\n \n")

# %%
remove_outliers(data1)

# %%
# Removing all the outliers will make the class even more worse, hence not proceeding with all outlier removal process
# we will have 4004 0.0 class and 317 1.0 class which is no good so we are not taking this method. We will remove the 
# outliers that belong to class 0 for now

# %%
def out_highspend(x):
    if x > 186.5 or x < -49.5:
        return np.nan
    else:
        return x

def out_MonthlyAverageSpend(x):
    if x> 5.26 or x < -2.03:
        return np.nan
    else:
        return x

def out_Mortgage(x):
    if x> 252.5 or x < -151.5:
        return np.nan
    else:
        return x

# %%
data1['out'] = data1['HighestSpend'].apply(out_highspend)

# %%
data1['out1'] = data1['MonthlyAverageSpend'].apply(out_MonthlyAverageSpend)

# %%
data1['out3'] = data1['Mortgage'].apply(out_Mortgage)

# %%
p = data1[data1['LoanOnCard']==0].dropna(axis=0)
#dropping the outliers where the class is 0

# %%
q = data1[data1['LoanOnCard']==1]

# %%
new_data = pd.concat([p,q])
new_data = new_data.drop(['out','out1','out3'],axis=1)

# %%
new_data['LoanOnCard'].value_counts()
# Out:
# 0.0    4105
# 1.0     480
# Name: LoanOnCard, dtype: int64

# %% [markdown]
# # Now we have very slightly balanced the classes from 4500:480 to 4105:480 by removing the outliers from class 0

# %%
# F. Again train the same previous model on balanced data. [1 Marks]

# %%
X = new_data.drop('LoanOnCard',axis=1)
y = new_data['LoanOnCard']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %%
SS = StandardScaler()
XL = SS.fit_transform(X_train)
XLe = SS.transform(X_test)
X_train = pd.DataFrame(XL,columns = [X_train.columns])
X_test = pd.DataFrame(XLe,columns = [X_test.columns])

# %%
LR = LogisticRegression()

# %%
LR.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
LR.score(X_train,y_train)
#score of training data
# Out:
# 0.9703315881326352

# %%
LR.score(X_test,y_test)
#score of testing data
# Out:
# 0.962510897994769

# %%
prediction = LR.predict(X_test)

# %%
postpred = pd.DataFrame(prediction,columns = ['Predicted data'])

# %%
postpred['Actual data'] = y_test.values

# %%
# G Print evaluation metrics and clearly share differences observed. [2 Marks

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      1029
#          1.0       0.86      0.76      0.81       118
#
#     accuracy                           0.96      1147
#    macro avg       0.92      0.87      0.89      1147
# weighted avg       0.96      0.96      0.96      1147

# %%
#insight

# We can see that precision is improved from 96% to 97% in class 0 and from 84% to 88% in class 1
# F1 score also improved from 97% to 98% for class 0 and from 71 to 82 for class 1

# %% [markdown]
# # 4.Performance Improvement: [10 Marks]

# %%
# A.Train a base model each for SVM, KNN. [4 Marks]

# %%
# Instantiate the Support Vector Classifier (SVC)
from sklearn.svm import SVC
svc = SVC(C=1.0, random_state=1, kernel='linear')
 
# Fit the model
svc.fit(XL, y_train)
# Out:
# SVC(kernel='linear', random_state=1)

# %%
# Make the predictions
y_predict = svc.predict(XLe)
 
# Measure the performance
print("Accuracy score %.3f" %metrics.accuracy_score(y_test, y_predict))
# Out:
# Accuracy score 0.960

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      1029
#          1.0       0.86      0.73      0.79       118
#
#     accuracy                           0.96      1147
#    macro avg       0.91      0.86      0.88      1147
# weighted avg       0.96      0.96      0.96      1147

# %%
#Design and train a KNN classifier.

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn.metrics import recall_score

Train_score =[]
Test_score =[]

for k in range(1,50):
    NNH = KNeighborsClassifier(n_neighbors = k, metric = 'euclidean', weights = 'distance' )
    NNH.fit(X_train, y_train)
    Train_score.append(NNH.score(X_train, y_train))
    Test_score.append(NNH.score(X_test, y_test))

# %%
plt.plot(range(1,50),Train_score)
plt.show()

# %%
plt.plot(range(1,50),Test_score)
plt.show()

# %% [markdown]
# # On test data model have higher accuracies for value of k less than 10. Let's choose k less than 10 to find best value of k.

# %%
# loading library
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn.metrics import recall_score

# instantiate learning model (k = 3)
knn = KNeighborsClassifier(n_neighbors = 3, weights = 'distance')

# fitting the model
knn.fit(X_train, y_train)

# predict the response
y_pred = knn.predict(X_test)

# evaluate accuracy and generate classification report
print('The accuracy score and Classification Report with K = 3 \n')
print('The model accuracy on test data is :' ,accuracy_score(y_test, y_pred),'\n')
print(classification_report(y_test, y_pred))

# instantiate learning model (k = 5)
knn = KNeighborsClassifier(n_neighbors=5, weights = 'distance')
# fitting the model
knn.fit(X_train, y_train)

# predict the response
y_pred = knn.predict(X_test)

# evaluate accuracy and generate classification report
print('The accuracy score and Classification Report with K = 5 \n')
print('The model accuracy on test data is :' ,accuracy_score(y_test, y_pred),'\n')
print(classification_report(y_test, y_pred))

# instantiate learning model (k = 7)
knn = KNeighborsClassifier(n_neighbors=7, weights = 'distance')

# fitting the model
knn.fit(X_train, y_train)

# predict the response
y_pred = knn.predict(X_test)

# evaluate accuracy and generate classification report
print('The accuracy score and Classification Report with K = 7 \n')
print('The model accuracy on test data is :' ,accuracy_score(y_test, y_pred),'\n')
print(classification_report(y_test, y_pred))
# Out:
# The accuracy score and Classification Report with K = 3
#
# The model accuracy on test data is : 0.9642545771578029
#
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      1029
#          1.0       0.92      0.71      0.80       118
#
#     accuracy                           0.96      1147
#    macro avg       0.95      0.85      0.89      1147
# weighted avg       0.96      0.96      0.96      1147
#
# The accuracy score and Classification Report with K = 5
#
# The model accuracy on test data is : 0.9616390584132519
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      1029
#          1.0       0.93      0.68      0.78       118
#
#     accuracy                           0.96      1147
#    macro avg       0.95      0.84      0.88      1147
# weighted avg       0.96      0.96      0.96      1147
#
# The accuracy score and Classification Report with K = 7
#
# ...

# %% [markdown]
# # Evaluating performance of the above models, it is observed that the KNN Classifier with K = 3 provide better Recall values and F1 Score compare to other models.

# %%
# Automate the task of finding best values of K for KNN.
myList = list(range(1,20))

# subsetting just the odd ones
neighbors = list(filter(lambda x: x % 2 != 0, myList))

# %%
# empty list that will hold accuracy scores
ac_scores = []
Recall_scores =[]

# perform accuracy metrics for values from 1,3,5....19
for k in neighbors:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    # predict the response
    y_pred = knn.predict(X_test)
    # evaluate accuracy
    scores = accuracy_score(y_test, y_pred)
    ac_scores.append(scores)
    # Evaluate Recall Score
    scores_r = recall_score(y_test, y_pred,average='macro')
    Recall_scores.append(scores_r)

# changing to misclassification error
MSE = [1 - x for x in ac_scores]
MSE_R = [1 - x for x in Recall_scores]

# determining best k based on accuracy score
optimal_k = neighbors[MSE.index(min(MSE))]
print("Based on accuracy score, The optimal number of neighbors is %d" % optimal_k)

# determining best k based on Recall score
optimal_k_R = neighbors[MSE_R.index(min(MSE_R))]
print("Based on Recall score, The optimal number of neighbors is %d" % optimal_k_R)
# Out:
# Based on accuracy score, The optimal number of neighbors is 3
# Based on Recall score, The optimal number of neighbors is 1

# %% [markdown]
# # THE FINAL BEST MODEL USING K=3

# %%
# Use k=3 as the final model for prediction

knn = KNeighborsClassifier(n_neighbors = 3,weights='distance')

# fitting the model
knn.fit(X_train, y_train)

# predict the response
y_pred = knn.predict(X_test)

# evaluate accuracy and Recall scores
print('The Training Score :{:.2f}'.format(knn.score(X_train,y_train)*100))
print('The Test Score :{:.2f}'.format(knn.score(X_test,y_test)*100),'\n')

print('The accuracy score of final trained model on test data is: {:.2f}'.format(accuracy_score(y_test, y_pred)))
print('The Recall score of final trained model on test data is : {:.2f}'.format(recall_score(y_test, y_pred,average='macro')))
# Out:
# The Training Score :100.00
# The Test Score :96.43
#
# The accuracy score of final trained model on test data is: 0.96
# The Recall score of final trained model on test data is : 0.85

# %%
# C. Print evaluation metrics for final model. [1 Marks]
#print(classification_report(y_train, y_pred))

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98      1029
#          1.0       0.92      0.71      0.80       118
#
#     accuracy                           0.96      1147
#    macro avg       0.95      0.85      0.89      1147
# weighted avg       0.96      0.96      0.96      1147

# %%
#D. Share improvement achieved from base model to final model. [2 Marks]

#We observe that the model performance is slightly poor than the previous model (oversampled train and test data)
#but model is free from data leakage and good predictor for Non Loan Holders.
